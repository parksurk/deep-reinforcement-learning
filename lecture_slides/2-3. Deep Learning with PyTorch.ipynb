# %%
from IPython.display import Image
Image(filename='./images/2-0-0-0_opening.jpg')

# %% [markdown]
# # Learning Plan

# %% [markdown]
# ### Lesson 2-1: Neural Networks (Optional)
# you are expected to know how neural networks train through backpropagation.
#
# ### Lesson 2-2: Convolutional Neural Networks (Optional)
# If you'd like to review convolutional neural networks, check out this lesson in the extracurricular content.
#
# ### Lesson 2-3: Deep Learning with PyTorch (Optional)
# We will use PyTorch throughout this program. If the PyTorch framework is new to you, please take a look at our introductory lesson in the extracurricular content.
#
# ### Lesson 2-4: Deep Q-Networks
# In this lesson, you will learn all of the details behind the Deep Q-Networks (DQN) algorithm.

# %% [markdown]
# ### Lesson 2-5: Deep RL in Robotics (Optional)
# Learn about how to use the Deep Q-Learning algorithm with real-world robotics from experts at NVIDIA's Deep Learning Institute.

# %% [markdown]
# ## Optional Resources
#
# * Study this Stanford University lecture [CS231n: Convolutional Neural Networks for Visual Recognition] { http://cs231n.stanford.edu }

# %% [markdown]
# # Lesson 2-3: Deep Learning with PyTorch
#
# ![](./images/2-3-0-0_pytorch_icon.png)
#
# * Home : https://pytorch.org
# * GitHub : https://github.com/pytorch/pytorch
#
# PyTorch was released in early 2017 and has been making a pretty big impact in the deep learning community. It's developed as an open source project by the [Facebook AI Research team](https://research.fb.com/category/facebook-ai-research/), but is being adopted by teams everywhere in industry and academia. In my experience, it's the best framework for learning deep learning and just a delight to work with in general. By the end of this lesson, you'll have trained your own deep learning model that can classify images of cats and dogs.

# %% [markdown]
# ## Hands-on Resources
#
# * Github URL : https://github.com/udacity/DL_PyTorch

# %% [markdown]
# ## 2-3-1 : Introducing PyTorch

# %%
from IPython.display import Image
Image(filename='./images/2-3-1-1_Introducing-pytorch.png')

# %%
from IPython.display import Image
Image(filename='./images/2-3-1-2_Introducing-pytorch.png')

# %%
from IPython.display import Image
Image(filename='./images/2-3-1-3_Introducing-pytorch.png')

# %%
from IPython.display import Image
Image(filename='./images/2-3-1-4_Introducing-pytorch.png')

# %% [markdown]
# ## 2-3-2 : PyTorch Tensors
#
# ### [Hands-on]
#
# <a href="../DL_PyTorch/Part 1 - Tensors in PyTorch.ipynb">Part 1 - Tensors in PyTorch</a>

# %% [markdown]
# ## 2-3-3 : Defining Networks
#
# ### [Hands-on]
#
# <a href="../DL_PyTorch/Part 2 - Neural Networks in PyTorch.ipynb">Part 2 - Neural Networks in PyTorch</a>

# %% [markdown]
# ## 2-3-4 : Training Networks
#
# ### [Hands-on]
#
# <a href="../DL_PyTorch/Part 3 - Training Neural Networks.ipynb">Part 3 - Training Neural Networks</a>

# %% [markdown]
# ## 2-3-5 : Fashion-MNIST Exercise
#
# ### [Hands-on]
#
# <a href="../DL_PyTorch/Part 4 - Fashion-MNIST Exercise.ipynb">Part 4 - Fashion-MNIST Exercise</a>

# %% [markdown]
# ## 2-3-6 : Inference & Validation
#
# ### [Hands-on]
#
# <a href="../DL_PyTorch/Part 5 - Inference and Validation.ipynb">Part 5 - Inference and Validation</a>

# %% [markdown]
# ## 2-3-7 : Saving and Loading Trained Networks
#
# ### [Hands-on]
#
# <a href="../DL_PyTorch/Part 6 - Saving and Loading Models.ipynb">Part 6 - Saving and Loading Models</a>

# %% [markdown]
# ## 2-3-8 : Loading Data Sets with Torchvision
#
# ### [Hands-on]
#
# <a href="../DL_PyTorch/Part 7 - Loading Image Data.ipynb">Part 7 - Loading Image Data</a>

# %% [markdown]
# ## 2-3-9 : Transfer Learning
#
# ### [Hands-on]
#
# <a href="../DL_PyTorch/Part 8 - Transfer Learning.ipynb">Part 8 - Transfer Learning</a>
